# %% [markdown]
# Component 2- **Models**
#
# There are 3 types of models
#
#
#
# 1.   Language Models
# 2.   Chat Models
# 3.   Embedding Models

# %%
#!pip install openai
#!pip install langchain

# %%
#!pip install tiktoken

# %%
import openai

# %%
openai_api_key=''

# %% [markdown]
# Language Models

# %%
from langchain.llms import OpenAI

llm = OpenAI(openai_api_key=openai_api_key, temperature = 0)

# %%
llm.model_name #Default Model Used, Other Models used are- https://platform.openai.com/docs/models/gpt-3-5
# Out:
# 'text-davinci-003'

# %%
llm("Tell me the days of the week?")
# Out:
# '\n\nMonday, Tuesday, Wednesday, Thursday, Friday, Saturday, Sunday.'

# %%
llm("Tell me a joke on lions")
# Out:
# '\n\nQ: What did the lion say when he saw the zebra?\nA: Nothing, he was speechless!'

# %%
llm("Tell me a joke on lions")
# Out:
# '\n\nQ: What did the lion say when he saw the zebra?\nA: Nothing, he was speechless!'

# %%
llm = OpenAI(openai_api_key=openai_api_key, temperature = 0.7)

# %%
llm("Tell me a joke on lions")
# Out:
# "\n\nQ: What did the lion say when he saw his reflection in the mirror?\nA: Oh my, I'm manely handsome!"

# %%
llm_result = llm.generate(["Tell me a joke", "Tell me a poem"]*2) #Pass a list

# %%
llm_result
# Out:
# LLMResult(generations=[[Generation(text='\n\nQ: What do you call a bear with no teeth?\nA: A gummy bear.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nRoses are red,\nViolets are blue,\nSugar is sweet,\nAnd so are you.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nQ: What did the fish say when it hit the wall?\nA: Dam!', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nRoses are red,\nViolets are blue,\nSugar is sweet,\nAnd so are you.', generation_info={'finish_reason': 'stop', 'logprobs': None})]], llm_output={'token_usage': {'prompt_tokens': 16, 'total_tokens': 110, 'completion_tokens': 94}, 'model_name': 'text-davinci-003'}, run=[RunInfo(run_id=UUID('2cf1f295-7b7b-4a15-a65d-3b8be5b0e0dc')), RunInfo(run_id=UUID('fbf1bb64-63bd-47fe-84e7-e7dda44888d5')), RunInfo(run_id=UUID('0bfa8fd3-1f3a-4a4c-9172-ec32e8b4f3cb')), RunInfo(run_id=UUID('667bf17c-d79f-4da3-b64a-eee9961
# ...

# %%
llm_result.generations[0]
# Out:
# [Generation(text='\n\nQ: What do you call a bear with no teeth?\nA: A gummy bear.', generation_info={'finish_reason': 'stop', 'logprobs': None})]

# %% [markdown]
# Chat Models

# %%
from langchain.chat_models import ChatOpenAI
chat = ChatOpenAI(openai_api_key=openai_api_key)

# %%
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)

# %%
messages = [
    SystemMessage(content="You are a helpful assistant that gives answers only in a single line"),
    HumanMessage(content="Tell me about skies")
]
chat(messages)
# Out:
# AIMessage(content='Skies are the expanse of atmosphere above the Earth, often characterized by the presence of clouds, the color blue, and the sun or stars.', additional_kwargs={}, example=False)

# %%
chat(
    [
        SystemMessage(content="You are a nice AI bot that helps a user figure out where to travel in one short sentence"),
        HumanMessage(content="I like the beaches where should I go?"),
        AIMessage(content="You should go to Nice, France"),
        HumanMessage(content="What else should I do when I'm there?")
    ]
)
# Out:
# AIMessage(content='You should explore the charming Old Town and indulge in delicious French cuisine.', additional_kwargs={}, example=False)

# %% [markdown]
# Embedding Models
#
# Models- https://openai.com/blog/new-and-improved-embedding-model

# %%
from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(openai_api_key=openai_api_key)

# %%
text = "Hi! It's time for the beach"

# %%
text_embedding = embeddings.embed_query(text)

# %%
text_embedding
# Out:
# [-0.00011466222223832396,
#  -0.003150652560942347,
#  -0.0007831145605424051,
#  -0.01950432835081537,
#  -0.015125558574222013,
#  0.03126999899971671,
#  -0.015986756329464405,
#  -0.011741411557204373,
#  0.009309435751938005,
#  -0.013609363480516216,
#  0.004967053681567476,
#  0.013524456659576826,
#  0.00897587230978206,
#  -0.0213844098199757,
#  -0.0009142653914444705,
#  -0.021238855269793886,
#  0.03012982168995918,
#  -0.003845069759260046,
#  0.014834448542535763,
#  0.0021211564257296108,
#  -0.012808812523193623,
#  -0.024028652677590544,
#  0.028261869766647338,
#  -0.0040724987439191285,
#  -0.009946236908983436,
#  -0.008205646148403302,
#  0.010722528774609061,
#  -0.015695647229100777,
#  -0.0013759466377560555,
#  -0.031100185357837932,
#  0.039784947635933744,
#  0.001792142145343488,
#  -0.0021044783001879447,
#  -0.012578351152072419,
#  -0.009843135769271318,
#  -0.02419846818211457,
#  -0.007914536116717052,
#  -0.0030611971603097744,
# ...

# %%
print (f"Your embedding is length {len(text_embedding)}")
# Out:
# Your embedding is length 1536
